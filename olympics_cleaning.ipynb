# %%
import pandas as pd
import pycountry

# %%
df= pd.read_csv('updated_olympics.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  id                      name sex   age  height  weight  \
# 0           0   1                 A Dijiang   M  24.0   180.0    80.0
# 1           1   2                  A Lamusi   M  23.0   170.0    60.0
# 2           2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3           3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4           4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
#
#              team  noc        games  year  season       city          sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               event medal alpha3code  numeric  medal_count
# ...

# %%
df.shape
# Out:
# (250542, 18)

# %%
df['medal'].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df['medal'].isna().sum()
# Out:
# np.int64(216129)

# %%
df['medal'].fillna("NA", inplace = True)
# Out:
# C:\Users\Justh\AppData\Local\Temp\ipykernel_21316\458899145.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['medal'].fillna("NA", inplace = True)

# %%
df['medal_count'] = df['medal'].apply(lambda x: 1 if x in ['Gold', 'Silver', 'Bronze'] else 0)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'sex', 'age', 'height', 'weight', 'team',
#        'noc', 'games', 'year', 'season', 'city', 'sport', 'event', 'medal',
#        'alpha3code', 'numeric', 'medal_count'],
#       dtype='object')

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#             id                      name sex   age  height  weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 250537  135569                Andrzej ya   M  29.0   179.0    89.0
# 250538  135570                  Piotr ya   M  27.0   176.0    59.0
# 250539  135570                  Piotr ya   M  27.0   176.0    59.0
# 250540  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 250541  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   team  noc        games  year  season            city  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.to_csv('updated_olympics.csv')

# %%
df['medal_count'].unique()
# Out:
# array([0, 1])

# %%
import pandas as pd

# Sample data
data = {
    'Region': ['North', 'South', 'North', 'East', 'South', 'East', 'North'],
    'Category': ['Electronics', 'Electronics', 'Clothing', 'Clothing', 'Clothing', 'Electronics', 'Clothing'],
    'Sales': [100, 200, 150, 300, 100, 250, 400]
}

# Create a DataFrame
df1 = pd.DataFrame(data)

# Group by Region and Category and calculate total sales
grouped = df1.groupby(['Region', 'Category']).sum().reset_index()

# %%
total_medal=df.groupby(['alpha3code']).sum(['medal_count'])

# %%
total_medal
# Out:
#             Unnamed: 0         id      age    height   weight     year  \
# alpha3code
# ABW            6400497    3468050   1044.0    7102.0   2919.0    83996
# AFG           16445633    8918075   1836.0    9212.0   4020.0   247720
# AGO           27926814   15151663   6651.0   43660.0  18165.0   534100
# ALB            9857019    5343261   1774.0    9861.0   4361.0   140158
# AND           20227519   10965602   3898.0   23450.0   9537.0   337498
# ...                ...        ...      ...       ...      ...      ...
# WSM            8121422    4406700   1622.0    8042.0   4245.5   125984
# YEM            1714984     932821    675.0    4199.0   1492.0    64092
# ZAF          224638064  121774378  41716.0  192186.0  78244.0  3384650
# ZMB           22368536   12125915   3613.0   22122.0   9179.0   363520
# ZWE           38112412   20670442   7787.0   49929.0  19698.0   618852
#
#             numeric  medal_count
# alpha3code
# ABW           22386            0
# ...

# %%
grouped
# Out:
#   Region     Category  Sales
# 0   East     Clothing    300
# 1   East  Electronics    250
# 2  North     Clothing    550
# 3  North  Electronics    100
# 4  South     Clothing    100
# 5  South  Electronics    200
